# %%
import xgboost as xgb
import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score, accuracy_score

# Hyperparameters tuning

from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %%
X_train_tumor = pd.read_csv(r"C:\Users\logiusti\Lorenzo\PyWorkspace\Camel-Blue\radiomics\radiomics_train_tumor_feature.csv")
X_train_no_tumor = pd.read_csv(r"C:\Users\logiusti\Lorenzo\PyWorkspace\Camel-Blue\radiomics\radiomics_train_no_tumor_feature.csv")

X_valid_tumor = pd.read_csv(r"C:\Users\logiusti\Lorenzo\PyWorkspace\Camel-Blue\radiomics\radiomics_valid_tumor_feature.csv")
X_valid_no_tumor = pd.read_csv(r"C:\Users\logiusti\Lorenzo\PyWorkspace\Camel-Blue\radiomics\radiomics_valid_no_tumor_feature.csv")

# %%
del X_train_tumor['Image_Name']
del X_train_no_tumor['Image_Name']
del X_valid_tumor['Image_Name']
del X_valid_no_tumor['Image_Name']

# %%
X_train = X_train_tumor.append(X_train_no_tumor, ignore_index=True).sample(frac=1)
X_valid = X_valid_tumor.append(X_valid_no_tumor, ignore_index=True)#.sample(frac=1)

# %%
y_train = X_train['Label'].to_numpy()
y_valid = X_valid['Label'].to_numpy()

del X_train['Label']
del X_valid['Label']

X_train = X_train.to_numpy()
X_valid = X_valid.to_numpy()

y_train = np.vectorize({'Tumor':1, 'No_Tumor':0}.get)(y_train)
y_valid = np.vectorize({'Tumor':1, 'No_Tumor':0}.get)(y_valid)

# %% [markdown]
# # Pick only the most relevant features N:20

# %%
X_train_backup = X_train
X_valid_backup = X_valid

# %%
X_train = X_train_backup
X_valid = X_valid_backup

# %%
X_train = X_train.transpose()[relev_features].transpose()
X_valid = X_valid.transpose()[relev_features].transpose()

# %%
X_train.shape

# %%
def score(params):
    print("Training with params: ")
    print(params)
    num_round = int(params['n_estimators'])
    del params['n_estimators']
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dvalid = xgb.DMatrix(X_valid, label=y_valid)
    watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
    gbm_model = xgb.train(params, dtrain, num_round,
                          evals=watchlist,
                          verbose_eval=True)
    predictions = gbm_model.predict(dvalid,
                                    ntree_limit=gbm_model.best_iteration + 1)
    score = roc_auc_score(y_valid, predictions.round())
    # TODO: Add the importance for the selected features
    print("\tScore {0}\n\n".format(score))
    # The score function should return the loss (1-score)
    # since the optimize function looks for the minimum
    loss = 1 - score
    return {'loss': loss, 'status': STATUS_OK}


def optimize(
             #trials, 
             random_state=1234):
    """
    This is the optimization function that given a space (space here) of 
    hyperparameters and a scoring function (score here), finds the best hyperparameters.
    """
    # To learn more about XGBoost parameters, head to this page: 
    # https://github.com/dmlc/xgboost/blob/master/doc/parameter.md
    space = {
        'n_estimators': hp.choice('n_estimators', np.arange(550, 5000, dtype=int)),
        'eta': hp.quniform('eta', 0.15, 1, 0.025),
        # A problem with max_depth casted to float instead of int with
        # the hp.quniform method.
        'max_depth':  hp.choice('max_depth', np.arange(1, 700, dtype=int)),
        'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),
        'subsample': hp.quniform('subsample', 0, 1, 0.005),
        'gamma': hp.quniform('gamma', 0, 1, 0.005),
        'colsample_bytree': hp.quniform('colsample_bytree', 0, 1, 0.005),
        'colsample_bylevel ': hp.quniform('colsample_bylevel ', 0, 1, 0.005),
        'colsample_bynode': hp.quniform('colsample_bynode', 0, 1, 0.005),
        'reg_alpha' : hp.quniform('reg_alpha', 0.003, 1, 0.003),
        'reg_lambda' : hp.quniform('reg_lambda', 0.003, 1, 0.003),
        'eval_metric': 'auc',
        'objective': 'binary:logistic',
        # Increase this number if you have more cores. Otherwise, remove it and it will default 
        # to the maxium number. 
        'nthread': 7,
        'booster': 'gbtree',
        'tree_method': 'gpu_hist',
        'silent': 1,
        'seed': random_state
    }
    # Use the fmin function from Hyperopt to find the best hyperparameters
    trials = Trials()
    best = fmin(score, space, algo=tpe.suggest, 
                trials=trials,
               max_evals=3)
    return best,trials



best_hyperparams,trials = optimize(
                            #trials
                            )
print("The best hyperparameters are: ", "\n")
print(best_hyperparams)
# Out:
# Training with params:
# {'booster': 'gbtree', 'colsample_bylevel ': 0.8300000000000001, 'colsample_bynode': 0.655, 'colsample_bytree': 0.645, 'eta': 0.9, 'eval_metric': 'auc', 'gamma': 0.72, 'max_depth': 230, 'min_child_weight': 3.0, 'n_estimators': 4406, 'nthread': 7, 'objective': 'binary:logistic', 'reg_alpha': 0.705, 'reg_lambda': 0.642, 'seed': 1234, 'silent': 1, 'subsample': 0.915, 'tree_method': 'gpu_hist'}
# [0]	eval-auc:0.80168	train-auc:0.92931
#
# [1]	eval-auc:0.76995	train-auc:0.97430
#
# [2]	eval-auc:0.77109	train-auc:0.99119
#
# [3]	eval-auc:0.77968	train-auc:0.99776
#
# [4]	eval-auc:0.78143	train-auc:0.99921
#
# [5]	eval-auc:0.79304	train-auc:0.99996
#
# [6]	eval-auc:0.79074	train-auc:0.99997
#
# [7]	eval-auc:0.80126	train-auc:0.99999
#
# [8]	eval-auc:0.80827	train-auc:1.00000
#
# [9]	eval-auc:0.81141	train-auc:1.00000
#
# [10]	eval-auc:0.81407	train-auc:1.00000
#
# [11]	eval-auc:0.81516	train-auc:1.00000
#
# [12]	eval-auc:0.81431	train-auc:1.00000
#
# [13]	eval-auc:0.81722	train-auc:1.00000
#
# [14]	eval-auc:0.81044	train-auc:1.00000
#
# [15]	eval-auc:0.80500	train-auc:1.00000
#
# [16]	eval-auc:0.80815	train-auc:1.00000
#
# [17]	eval-auc:0.81032	train-auc:1.00000
#
# [18]	eval-auc:0.80754	train-auc:1.00000
#
# [19]	eval-auc:0.80863	train-auc:1.00000
#
# [20]	eval-auc:0.80972	train-auc:1.00000
#
# [21]	eval-auc:0.80718	train-auc:1.00000
#
# [22]	eval-auc:0.80476	train-auc:1.00000
#
# [23]	eval-auc:0.80368	train-auc:1.00000
#
# [24]	eval-auc:0.79860	train-auc:1.00000
#
# [25]	eval-auc:0.79872	train-auc:1.00000
#
# [26]	eval-auc:0.80077	train-auc:1.00000
#
# [27]	eval-auc:0.79981	train-auc:1.00000
#
# [28]	eval-auc:0.80077	train-auc:1.00000
#
# [29]	eval-auc:0.80114	train-auc:1.00000
#
# [30]	eval-auc:0.80295	train-auc:1.00000
#
# [31]	eval-auc:0.80198	train-auc:1.00000
#
# [32]	eval-auc:0.80549	train-auc:1.00000
#
# [33]	eval-auc:0.80222	train-auc:1.00000
#
# [34]	eval-auc:0.80343	train-auc:1.00000
#
# [35]	eval-auc:0.80138	train-auc:1.00000
#
# [36]	eval-auc:0.79872	train-auc:1.00000
#
# [37]	eval-auc:0.79546	train-auc:1.00000
#
# [38]	eval-auc:0.79799	train-auc:1.00000
#
# [39]	eval-auc:0.79763	train-auc:1.00000
#
# [40]	eval-auc:0.79860	train-auc:1.00000
#
# [41]	eval-auc:0.79956	train-auc:1.00000
#
# [42]	eval-auc:0.80138	train-auc:1.00000
#
# [43]	eval-auc:0.80247	train-auc:1.00000
#
# [44]	eval-auc:0.80464	train-auc:1.00000
#
# [45]	eval-auc:0.80380	train-auc:1.00000
#
# [46]	eval-auc:0.80404	train-auc:1.00000
#
# [47]	eval-auc:0.80537	train-auc:1.00000
#
# [48]	eval-auc:0.80537	train-auc:1.00000
#
# [49]	eval-auc:0.80585	train-auc:1.00000
#
# [50]	eval-auc:0.80549	train-auc:1.00000
#
# [51]	eval-auc:0.80694	train-auc:1.00000
#
# [52]	eval-auc:0.80851	train-auc:1.00000
#
# [53]	eval-auc:0.80791	train-auc:1.00000
#
# [54]	eval-auc:0.80742	train-auc:1.00000
#
# [55]	eval-auc:0.80646	train-auc:1.00000
#
# [56]	eval-auc:0.80706	train-auc:1.00000
#
# [57]	eval-auc:0.80488	train-auc:1.00000
#
# [58]	eval-auc:0.80464	train-auc:1.00000
#
# [59]	eval-auc:0.80694	train-auc:1.00000
#
# [60]	eval-auc:0.80851	train-auc:1.00000
#
# [61]	eval-auc:0.80754	train-auc:1.00000
#
# [62]	eval-auc:0.80742	train-auc:1.00000
# [63]	eval-auc:0.80718	train-auc:1.00000
#
# [64]	eval-auc:0.80803	train-auc:1.00000
#
# [65]	eval-auc:0.80815	train-auc:1.00000
#
# [66]	eval-auc:0.80912	train-auc:1.00000
#
# [67]	eval-auc:0.81069	train-auc:1.00000
#
# [68]	eval-auc:0.81020	train-auc:1.00000
#
# [69]	eval-auc:0.81008	train-auc:1.00000
#
# [70]	eval-auc:0.81057	train-auc:1.00000
#
# [71]	eval-auc:0.81069	train-auc:1.00000
#
# [72]	eval-auc:0.80996	train-auc:1.00000
#
# [73]	eval-auc:0.81020	train-auc:1.00000
#
# [74]	eval-auc:0.81165	train-auc:1.00000
#
# [75]	eval-auc:0.81153	train-auc:1.00000
#
# [76]	eval-auc:0.81093	train-auc:1.00000
#
# [77]	eval-auc:0.81093	train-auc:1.00000
#
# [78]	eval-auc:0.81069	train-auc:1.00000
#
# [79]	eval-auc:0.81057	train-auc:1.00000
#
# [80]	eval-auc:0.80936	train-auc:1.00000
#
# [81]	eval-auc:0.81105	train-auc:1.00000
#
# [82]	eval-auc:0.81093	train-auc:1.00000
#
# [83]	eval-auc:0.81117	train-auc:1.00000
#
# [84]	eval-auc:0.81153	train-auc:1.00000
#
# [85]	eval-auc:0.81226	train-auc:1.00000
#
# [86]	eval-auc:0.81105	train-auc:1.00000
#
# [87]	eval-auc:0.81044	train-auc:1.00000
#
# [88]	eval-auc:0.80996	train-auc:1.00000
#
# [89]	eval-auc:0.80996	train-auc:1.00000
#
# [90]	eval-auc:0.81032	train-auc:1.00000
#
# [91]	eval-auc:0.80815	train-auc:1.00000
#
# [92]	eval-auc:0.80815	train-auc:1.00000
#
# [93]	eval-auc:0.80815	train-auc:1.00000
#
# [94]	eval-auc:0.80851	train-auc:1.00000
#
# [95]	eval-auc:0.80815	train-auc:1.00000
#
# [96]	eval-auc:0.80827	train-auc:1.00000
#
# [97]	eval-auc:0.80839	train-auc:1.00000
#
# [98]	eval-auc:0.80875	train-auc:1.00000
#
# [99]	eval-auc:0.80936	train-auc:1.00000
#
# [100]	eval-auc:0.80936	train-auc:1.00000
#
# [101]	eval-auc:0.80936	train-auc:1.00000
#
# [102]	eval-auc:0.80960	train-auc:1.00000
#
# [103]	eval-auc:0.80996	train-auc:1.00000
#
# [104]	eval-auc:0.81008	train-auc:1.00000
#
# [105]	eval-auc:0.80972	train-auc:1.00000
#
# [106]	eval-auc:0.80936	train-auc:1.00000
#
# [107]	eval-auc:0.80936	train-auc:1.00000
#
# [108]	eval-auc:0.80936	train-auc:1.00000
#
# [109]	eval-auc:0.80936	train-auc:1.00000
#
# [110]	eval-auc:0.80936	train-auc:1.00000
#
# [111]	eval-auc:0.80936	train-auc:1.00000
#
# [112]	eval-auc:0.80936	train-auc:1.00000
#
# [113]	eval-auc:0.80948	train-auc:1.00000
#
# [114]	eval-auc:0.80887	train-auc:1.00000
#
# [115]	eval-auc:0.81032	train-auc:1.00000
#
# [116]	eval-auc:0.81069	train-auc:1.00000
#
# [117]	eval-auc:0.80996	train-auc:1.00000
#
# [118]	eval-auc:0.80996	train-auc:1.00000
#
# [119]	eval-auc:0.80996	train-auc:1.00000
#
# [120]	eval-auc:0.80996	train-auc:1.00000
#
# [121]	eval-auc:0.80996	train-auc:1.00000
#
# [122]	eval-auc:0.80996	train-auc:1.00000
#
# [123]	eval-auc:0.81008	train-auc:1.00000
#
# [124]	eval-auc:0.81008	train-auc:1.00000
#
# [125]	eval-auc:0.81008	train-auc:1.00000
#
# [126]	eval-auc:0.80936	train-auc:1.00000
#
# [127]	eval-auc:0.80851	train-auc:1.00000
#
# [128]	eval-auc:0.80875	train-auc:1.00000
#
# [129]	eval-auc:0.80875	train-auc:1.00000
# [130]	eval-auc:0.80875	train-auc:1.00000
#
# [131]	eval-auc:0.80875	train-auc:1.00000
#
# [132]	eval-auc:0.80875	train-auc:1.00000
#
# [133]	eval-auc:0.80887	train-auc:1.00000
#
# [134]	eval-auc:0.80887	train-auc:1.00000
#
# [135]	eval-auc:0.80875	train-auc:1.00000
#
# [136]	eval-auc:0.80875	train-auc:1.00000
#
# [137]	eval-auc:0.80899	train-auc:1.00000
#
# [138]	eval-auc:0.80899	train-auc:1.00000
#
# [139]	eval-auc:0.80960	train-auc:1.00000
#
# [140]	eval-auc:0.80960	train-auc:1.00000
#
# [141]	eval-auc:0.80960	train-auc:1.00000
#
# [142]	eval-auc:0.80960	train-auc:1.00000
#
# [143]	eval-auc:0.80960	train-auc:1.00000
#
# [144]	eval-auc:0.80936	train-auc:1.00000
#
# [145]	eval-auc:0.80936	train-auc:1.00000
#
# [146]	eval-auc:0.80984	train-auc:1.00000
#
# [147]	eval-auc:0.80984	train-auc:1.00000
#
# [148]	eval-auc:0.80984	train-auc:1.00000
#
# [149]	eval-auc:0.80984	train-auc:1.00000
#
# [150]	eval-auc:0.80972	train-auc:1.00000
#
# [151]	eval-auc:0.80972	train-auc:1.00000
#
# [152]	eval-auc:0.80924	train-auc:1.00000
#
# [153]	eval-auc:0.80924	train-auc:1.00000
#
# [154]	eval-auc:0.80936	train-auc:1.00000
#
# [155]	eval-auc:0.80984	train-auc:1.00000
#
# [156]	eval-auc:0.80984	train-auc:1.00000
#
# [157]	eval-auc:0.80984	train-auc:1.00000
#
# [158]	eval-auc:0.80984	train-auc:1.00000
#
# [159]	eval-auc:0.80996	train-auc:1.00000
#
# [160]	eval-auc:0.81020	train-auc:1.00000
#
# [161]	eval-auc:0.81020	train-auc:1.00000
#
# [162]	eval-auc:0.81020	train-auc:1.00000
#
# [163]	eval-auc:0.81020	train-auc:1.00000
#
# [164]	eval-auc:0.81020	train-auc:1.00000
#
# [165]	eval-auc:0.81020	train-auc:1.00000
#
# [166]	eval-auc:0.81020	train-auc:1.00000
#
# [167]	eval-auc:0.81020	train-auc:1.00000
#
# [168]	eval-auc:0.81020	train-auc:1.00000
#
# [169]	eval-auc:0.81020	train-auc:1.00000
#
# [170]	eval-auc:0.80936	train-auc:1.00000
#
# [171]	eval-auc:0.80936	train-auc:1.00000
#
# [172]	eval-auc:0.80875	train-auc:1.00000
#
# [173]	eval-auc:0.80875	train-auc:1.00000
#
# [174]	eval-auc:0.80875	train-auc:1.00000
#
# [175]	eval-auc:0.80875	train-auc:1.00000
#
# [176]	eval-auc:0.80851	train-auc:1.00000
#
# [177]	eval-auc:0.80912	train-auc:1.00000
#
# [178]	eval-auc:0.80936	train-auc:1.00000
#
# [179]	eval-auc:0.80936	train-auc:1.00000
#
# [180]	eval-auc:0.80936	train-auc:1.00000
#
# [181]	eval-auc:0.80839	train-auc:1.00000
#
# [182]	eval-auc:0.80839	train-auc:1.00000
#
# [183]	eval-auc:0.80839	train-auc:1.00000
#
# [184]	eval-auc:0.80839	train-auc:1.00000
#
# [185]	eval-auc:0.80839	train-auc:1.00000
#
# [186]	eval-auc:0.80839	train-auc:1.00000
#
# [187]	eval-auc:0.80839	train-auc:1.00000
#
# [188]	eval-auc:0.80851	train-auc:1.00000
#
# [189]	eval-auc:0.80851	train-auc:1.00000
#
# [190]	eval-auc:0.80912	train-auc:1.00000
#
# [191]	eval-auc:0.80912	train-auc:1.00000
#
# [192]	eval-auc:0.80912	train-auc:1.00000
#
# [193]	eval-auc:0.80912	train-auc:1.00000
#
# [194]	eval-auc:0.80912	train-auc:1.00000
#
# [195]	eval-auc:0.80924	train-auc:1.00000
#
# [196]	eval-auc:0.80924	train-auc:1.00000
# [197]	eval-auc:0.80948	train-auc:1.00000
#
# [198]	eval-auc:0.81032	train-auc:1.00000
#
# [199]	eval-auc:0.81032	train-auc:1.00000
#
# [200]	eval-auc:0.81032	train-auc:1.00000
#
# [201]	eval-auc:0.80960	train-auc:1.00000
#
# [202]	eval-auc:0.81008	train-auc:1.00000
#
# [203]	eval-auc:0.81008	train-auc:1.00000
#
# [204]	eval-auc:0.81008	train-auc:1.00000
#
# [205]	eval-auc:0.81069	train-auc:1.00000
#
# [206]	eval-auc:0.80996	train-auc:1.00000
#
# [207]	eval-auc:0.80996	train-auc:1.00000
#
# [208]	eval-auc:0.80996	train-auc:1.00000
#
# [209]	eval-auc:0.80996	train-auc:1.00000
#
# [210]	eval-auc:0.80960	train-auc:1.00000
#
# [211]	eval-auc:0.80960	train-auc:1.00000
#
# [212]	eval-auc:0.80960	train-auc:1.00000
#
# [213]	eval-auc:0.80960	train-auc:1.00000
#
# [214]	eval-auc:0.80960	train-auc:1.00000
#
# [215]	eval-auc:0.80960	train-auc:1.00000
#
# [216]	eval-auc:0.80960	train-auc:1.00000
#
# [217]	eval-auc:0.80960	train-auc:1.00000
#
# [218]	eval-auc:0.80960	train-auc:1.00000
#
# [219]	eval-auc:0.80960	train-auc:1.00000
#
# [220]	eval-auc:0.80960	train-auc:1.00000
#
# [221]	eval-auc:0.80960	train-auc:1.00000
#
# [222]	eval-auc:0.80960	train-auc:1.00000
#
# [223]	eval-auc:0.80960	train-auc:1.00000
#
# [224]	eval-auc:0.80960	train-auc:1.00000
#
# [225]	eval-auc:0.81008	train-auc:1.00000
#
# [226]	eval-auc:0.81008	train-auc:1.00000
#
# [227]	eval-auc:0.81008	train-auc:1.00000
#
# [228]	eval-auc:0.81008	train-auc:1.00000
#
# [229]	eval-auc:0.81008	train-auc:1.00000
#
# [230]	eval-auc:0.81008	train-auc:1.00000
#
# [231]	eval-auc:0.81008	train-auc:1.00000
#
# [232]	eval-auc:0.81008	train-auc:1.00000
#
# [233]	eval-auc:0.81008	train-auc:1.00000
#
# [234]	eval-auc:0.81008	train-auc:1.00000
#
# [235]	eval-auc:0.81008	train-auc:1.00000
#
# [236]	eval-auc:0.81008	train-auc:1.00000
#
# [237]	eval-auc:0.81008	train-auc:1.00000
#
# [238]	eval-auc:0.81008	train-auc:1.00000
#
# [239]	eval-auc:0.81008	train-auc:1.00000
#
# [240]	eval-auc:0.81008	train-auc:1.00000
#
# [241]	eval-auc:0.81008	train-auc:1.00000
#
# [242]	eval-auc:0.81008	train-auc:1.00000
#
# [243]	eval-auc:0.81008	train-auc:1.00000
#
# [244]	eval-auc:0.81008	train-auc:1.00000
#
# [245]	eval-auc:0.81008	train-auc:1.00000
#
# [246]	eval-auc:0.81008	train-auc:1.00000
#
# [247]	eval-auc:0.81008	train-auc:1.00000
#
# [248]	eval-auc:0.81008	train-auc:1.00000
#
# [249]	eval-auc:0.81008	train-auc:1.00000
#
# [250]	eval-auc:0.81008	train-auc:1.00000
#
# [251]	eval-auc:0.81008	train-auc:1.00000
#
# [252]	eval-auc:0.81008	train-auc:1.00000
#
# [253]	eval-auc:0.81008	train-auc:1.00000
#
# [254]	eval-auc:0.81008	train-auc:1.00000
#
# [255]	eval-auc:0.81008	train-auc:1.00000
#
# [256]	eval-auc:0.81008	train-auc:1.00000
#
# [257]	eval-auc:0.81008	train-auc:1.00000
#
# [258]	eval-auc:0.81008	train-auc:1.00000
#
# [259]	eval-auc:0.80948	train-auc:1.00000
#
# [260]	eval-auc:0.80948	train-auc:1.00000
#
# [261]	eval-auc:0.80948	train-auc:1.00000
#
# [262]	eval-auc:0.80948	train-auc:1.00000
#
# [263]	eval-auc:0.80948	train-auc:1.00000
# [264]	eval-auc:0.80948	train-auc:1.00000
#
# [265]	eval-auc:0.80948	train-auc:1.00000
#
# [266]	eval-auc:0.80924	train-auc:1.00000
#
# [267]	eval-auc:0.80924	train-auc:1.00000
#
# [268]	eval-auc:0.80924	train-auc:1.00000
#
# [269]	eval-auc:0.80924	train-auc:1.00000
#
# [270]	eval-auc:0.80924	train-auc:1.00000
#
# [271]	eval-auc:0.80924	train-auc:1.00000
#
# [272]	eval-auc:0.80924	train-auc:1.00000
#
# [273]	eval-auc:0.80924	train-auc:1.00000
#
# [274]	eval-auc:0.80924	train-auc:1.00000
#
# [275]	eval-auc:0.80924	train-auc:1.00000
#
# [276]	eval-auc:0.80924	train-auc:1.00000
#
# [277]	eval-auc:0.80924	train-auc:1.00000
#
# [278]	eval-auc:0.80924	train-auc:1.00000
#
# [279]	eval-auc:0.80924	train-auc:1.00000
#
# [280]	eval-auc:0.80924	train-auc:1.00000
#
# [281]	eval-auc:0.80924	train-auc:1.00000
#
# [282]	eval-auc:0.80924	train-auc:1.00000
#
# [283]	eval-auc:0.80924	train-auc:1.00000
#
# [284]	eval-auc:0.80924	train-auc:1.00000
#
# [285]	eval-auc:0.80924	train-auc:1.00000
#
# [286]	eval-auc:0.80924	train-auc:1.00000
#
# [287]	eval-auc:0.80924	train-auc:1.00000
#
# [288]	eval-auc:0.80924	train-auc:1.00000
#
# [289]	eval-auc:0.80924	train-auc:1.00000
#
# [290]	eval-auc:0.80924	train-auc:1.00000
#
# [291]	eval-auc:0.80924	train-auc:1.00000
#
# [292]	eval-auc:0.80924	train-auc:1.00000
#
# [293]	eval-auc:0.80924	train-auc:1.00000
#
# [294]	eval-auc:0.80924	train-auc:1.00000
#
# [295]	eval-auc:0.80924	train-auc:1.00000
#
# [296]	eval-auc:0.80924	train-auc:1.00000
#
# [297]	eval-auc:0.80924	train-auc:1.00000
#
# [298]	eval-auc:0.80924	train-auc:1.00000
#
# [299]	eval-auc:0.80924	train-auc:1.00000
#
# [300]	eval-auc:0.80924	train-auc:1.00000
#
# [301]	eval-auc:0.80924	train-auc:1.00000
#
# [302]	eval-auc:0.80924	train-auc:1.00000
#
# [303]	eval-auc:0.80948	train-auc:1.00000
#
# [304]	eval-auc:0.80948	train-auc:1.00000
#
# [305]	eval-auc:0.80948	train-auc:1.00000
#
# [306]	eval-auc:0.80948	train-auc:1.00000
#
# [307]	eval-auc:0.80875	train-auc:1.00000
#
# [308]	eval-auc:0.80875	train-auc:1.00000
#
# [309]	eval-auc:0.80875	train-auc:1.00000
#
# [310]	eval-auc:0.80875	train-auc:1.00000
#
# [311]	eval-auc:0.80875	train-auc:1.00000
#
# [312]	eval-auc:0.80875	train-auc:1.00000
#
# [313]	eval-auc:0.80875	train-auc:1.00000
#
# [314]	eval-auc:0.80875	train-auc:1.00000
#
# [315]	eval-auc:0.80875	train-auc:1.00000
#
# [316]	eval-auc:0.80875	train-auc:1.00000
#
# [317]	eval-auc:0.80875	train-auc:1.00000
#
# [318]	eval-auc:0.80875	train-auc:1.00000
#
# [319]	eval-auc:0.80875	train-auc:1.00000
#
# [320]	eval-auc:0.80875	train-auc:1.00000
#
# [321]	eval-auc:0.80875	train-auc:1.00000
#
# [322]	eval-auc:0.80875	train-auc:1.00000
#
# [323]	eval-auc:0.80875	train-auc:1.00000
#
# [324]	eval-auc:0.80875	train-auc:1.00000
#
# [325]	eval-auc:0.80875	train-auc:1.00000
#
# [326]	eval-auc:0.80875	train-auc:1.00000
#
# [327]	eval-auc:0.80875	train-auc:1.00000
#
# [328]	eval-auc:0.80875	train-auc:1.00000
#
# [329]	eval-auc:0.80875	train-auc:1.00000
#
# [330]	eval-auc:0.80875	train-auc:1.00000
# [331]	eval-auc:0.80875	train-auc:1.00000
#
# [332]	eval-auc:0.80875	train-auc:1.00000
#
# [333]	eval-auc:0.80875	train-auc:1.00000
#
# [334]	eval-auc:0.80960	train-auc:1.00000
#
# [335]	eval-auc:0.80960	train-auc:1.00000
#
# [336]	eval-auc:0.80960	train-auc:1.00000
#
# [337]	eval-auc:0.80960	train-auc:1.00000
#
# [338]	eval-auc:0.80972	train-auc:1.00000
#
# [339]	eval-auc:0.80972	train-auc:1.00000
#
# [340]	eval-auc:0.81020	train-auc:1.00000
#
# [341]	eval-auc:0.81020	train-auc:1.00000
#
# [342]	eval-auc:0.81032	train-auc:1.00000
#
# [343]	eval-auc:0.80972	train-auc:1.00000
#
# [344]	eval-auc:0.80972	train-auc:1.00000
#
# [345]	eval-auc:0.80972	train-auc:1.00000
#
# [346]	eval-auc:0.80972	train-auc:1.00000
#
# [347]	eval-auc:0.80972	train-auc:1.00000
#
# [348]	eval-auc:0.80972	train-auc:1.00000
#
# [349]	eval-auc:0.80972	train-auc:1.00000
#
# [350]	eval-auc:0.80972	train-auc:1.00000
#
# [351]	eval-auc:0.80972	train-auc:1.00000
#
# [352]	eval-auc:0.80936	train-auc:1.00000
#
# [353]	eval-auc:0.80936	train-auc:1.00000
#
# [354]	eval-auc:0.80948	train-auc:1.00000
#
# [355]	eval-auc:0.80948	train-auc:1.00000
#
# [356]	eval-auc:0.80948	train-auc:1.00000
#
# [357]	eval-auc:0.80948	train-auc:1.00000
#
# [358]	eval-auc:0.80960	train-auc:1.00000
#
# [359]	eval-auc:0.80960	train-auc:1.00000
#
# [360]	eval-auc:0.80960	train-auc:1.00000
#
# [361]	eval-auc:0.80960	train-auc:1.00000
#
# [362]	eval-auc:0.80960	train-auc:1.00000
#
# [363]	eval-auc:0.80960	train-auc:1.00000
#
# [364]	eval-auc:0.80960	train-auc:1.00000
#
# [365]	eval-auc:0.80960	train-auc:1.00000
#
# [366]	eval-auc:0.80960	train-auc:1.00000
#
# [367]	eval-auc:0.80960	train-auc:1.00000
#
# [368]	eval-auc:0.80960	train-auc:1.00000
#
# [369]	eval-auc:0.80960	train-auc:1.00000
#
# [370]	eval-auc:0.80960	train-auc:1.00000
#
# [371]	eval-auc:0.80996	train-auc:1.00000
#
# [372]	eval-auc:0.80996	train-auc:1.00000
#
# [373]	eval-auc:0.80996	train-auc:1.00000
#
# [374]	eval-auc:0.80996	train-auc:1.00000
#
# [375]	eval-auc:0.80996	train-auc:1.00000
#
# [376]	eval-auc:0.80972	train-auc:1.00000
#
# [377]	eval-auc:0.80972	train-auc:1.00000
#
# [378]	eval-auc:0.80972	train-auc:1.00000
#
# [379]	eval-auc:0.80972	train-auc:1.00000
#
# [380]	eval-auc:0.80972	train-auc:1.00000
#
# [381]	eval-auc:0.80972	train-auc:1.00000
#
# [382]	eval-auc:0.80972	train-auc:1.00000
#
# [383]	eval-auc:0.80972	train-auc:1.00000
#
# [384]	eval-auc:0.80972	train-auc:1.00000
#
# [385]	eval-auc:0.80972	train-auc:1.00000
#
# [386]	eval-auc:0.80972	train-auc:1.00000
#
# [387]	eval-auc:0.80972	train-auc:1.00000
#
# [388]	eval-auc:0.80972	train-auc:1.00000
#
# [389]	eval-auc:0.80972	train-auc:1.00000
#
# [390]	eval-auc:0.80972	train-auc:1.00000
#
# [391]	eval-auc:0.80972	train-auc:1.00000
#
# [392]	eval-auc:0.80972	train-auc:1.00000
#
# [393]	eval-auc:0.80972	train-auc:1.00000
#
# [394]	eval-auc:0.80972	train-auc:1.00000
#
# ...
#
# [1036]	eval-auc:0.80936	train-auc:1.00000
#
# [1037]	eval-auc:0.80887	train-auc:1.00000
#
# [1038]	eval-auc:0.80887	train-auc:1.00000
#
# [1039]	eval-auc:0.80887	train-auc:1.00000
#
# [1040]	eval-auc:0.80887	train-auc:1.00000
#
# [1041]	eval-auc:0.80887	train-auc:1.00000
#
# [1042]	eval-auc:0.80887	train-auc:1.00000
#
# [1043]	eval-auc:0.80887	train-auc:1.00000
#
# [1044]	eval-auc:0.80887	train-auc:1.00000
#
# [1045]	eval-auc:0.80887	train-auc:1.00000
#
# [1046]	eval-auc:0.80887	train-auc:1.00000
#
# [1047]	eval-auc:0.80887	train-auc:1.00000
#
# [1048]	eval-auc:0.80887	train-auc:1.00000
#
# [1049]	eval-auc:0.80887	train-auc:1.00000
#
# [1050]	eval-auc:0.80887	train-auc:1.00000
#
# [1051]	eval-auc:0.80887	train-auc:1.00000
#
# [1052]	eval-auc:0.80912	train-auc:1.00000
#
# [1053]	eval-auc:0.80912	train-auc:1.00000
#
# [1054]	eval-auc:0.80912	train-auc:1.00000
#
# [1055]	eval-auc:0.80912	train-auc:1.00000
#
# [1056]	eval-auc:0.80912	train-auc:1.00000
#
# [1057]	eval-auc:0.80912	train-auc:1.00000
#
# [1058]	eval-auc:0.80912	train-auc:1.00000
#
# [1059]	eval-auc:0.80912	train-auc:1.00000
#
# [1060]	eval-auc:0.80912	train-auc:1.00000
#
# [1061]	eval-auc:0.80912	train-auc:1.00000
#
# [1062]	eval-auc:0.80912	train-auc:1.00000
#
# [1063]	eval-auc:0.80912	train-auc:1.00000
#
# [1064]	eval-auc:0.80912	train-auc:1.00000
#
# [1065]	eval-auc:0.80912	train-auc:1.00000
#
# [1066]	eval-auc:0.80912	train-auc:1.00000
#
# [1067]	eval-auc:0.80912	train-auc:1.00000
#
# [1068]	eval-auc:0.80912	train-auc:1.00000
#
# [1069]	eval-auc:0.80912	train-auc:1.00000
#
# [1070]	eval-auc:0.80912	train-auc:1.00000
#
# [1071]	eval-auc:0.80912	train-auc:1.00000
#
# [1072]	eval-auc:0.80912	train-auc:1.00000
# [1073]	eval-auc:0.80912	train-auc:1.00000
#
# [1074]	eval-auc:0.80912	train-auc:1.00000
#
# [1075]	eval-auc:0.80912	train-auc:1.00000
#
# [1076]	eval-auc:0.80912	train-auc:1.00000
#
# [1077]	eval-auc:0.80912	train-auc:1.00000
#
# [1078]	eval-auc:0.80912	train-auc:1.00000
#
# [1079]	eval-auc:0.80912	train-auc:1.00000
#
# [1080]	eval-auc:0.80912	train-auc:1.00000
#
# [1081]	eval-auc:0.80912	train-auc:1.00000
#
# [1082]	eval-auc:0.80912	train-auc:1.00000
#
# [1083]	eval-auc:0.80912	train-auc:1.00000
#
# [1084]	eval-auc:0.80912	train-auc:1.00000
#
# [1085]	eval-auc:0.80912	train-auc:1.00000
#
# [1086]	eval-auc:0.80912	train-auc:1.00000
#
# [1087]	eval-auc:0.80912	train-auc:1.00000
#
# [1088]	eval-auc:0.80912	train-auc:1.00000
#
# [1089]	eval-auc:0.80912	train-auc:1.00000
#
# [1090]	eval-auc:0.80912	train-auc:1.00000
#
# [1091]	eval-auc:0.80912	train-auc:1.00000
#
# [1092]	eval-auc:0.80912	train-auc:1.00000
#
# [1093]	eval-auc:0.80912	train-auc:1.00000
#
# [1094]	eval-auc:0.80912	train-auc:1.00000
#
# [1095]	eval-auc:0.80912	train-auc:1.00000
#
# [1096]	eval-auc:0.80912	train-auc:1.00000
#
# [1097]	eval-auc:0.80912	train-auc:1.00000
#
# [1098]	eval-auc:0.80912	train-auc:1.00000
#
# [1099]	eval-auc:0.80912	train-auc:1.00000
#
# [1100]	eval-auc:0.80912	train-auc:1.00000
#
# [1101]	eval-auc:0.80912	train-auc:1.00000
#
# [1102]	eval-auc:0.80912	train-auc:1.00000
#
# [1103]	eval-auc:0.80912	train-auc:1.00000
#
# [1104]	eval-auc:0.80912	train-auc:1.00000
#
# [1105]	eval-auc:0.80912	train-auc:1.00000
#
# [1106]	eval-auc:0.80912	train-auc:1.00000
#
# [1107]	eval-auc:0.80912	train-auc:1.00000
#
# [1108]	eval-auc:0.80912	train-auc:1.00000
#
# [1109]	eval-auc:0.80912	train-auc:1.00000
#
# [1110]	eval-auc:0.80912	train-auc:1.00000
#
# [1111]	eval-auc:0.80912	train-auc:1.00000
#
# [1112]	eval-auc:0.80912	train-auc:1.00000
#
# [1113]	eval-auc:0.80912	train-auc:1.00000
#
# [1114]	eval-auc:0.80912	train-auc:1.00000
#
# [1115]	eval-auc:0.80912	train-auc:1.00000
#
# [1116]	eval-auc:0.80912	train-auc:1.00000
#
# [1117]	eval-auc:0.80912	train-auc:1.00000
#
# [1118]	eval-auc:0.80912	train-auc:1.00000
#
# [1119]	eval-auc:0.80912	train-auc:1.00000
#
# [1120]	eval-auc:0.80912	train-auc:1.00000
#
# [1121]	eval-auc:0.80912	train-auc:1.00000
#
# [1122]	eval-auc:0.80912	train-auc:1.00000
#
# [1123]	eval-auc:0.80912	train-auc:1.00000
#
# [1124]	eval-auc:0.80912	train-auc:1.00000
#
# [1125]	eval-auc:0.80912	train-auc:1.00000
#
# [1126]	eval-auc:0.80912	train-auc:1.00000
#
# [1127]	eval-auc:0.80912	train-auc:1.00000
#
# [1128]	eval-auc:0.80912	train-auc:1.00000
#
# [1129]	eval-auc:0.80912	train-auc:1.00000
#
# [1130]	eval-auc:0.80912	train-auc:1.00000
#
# [1131]	eval-auc:0.80912	train-auc:1.00000
#
# [1132]	eval-auc:0.80912	train-auc:1.00000
#
# [1133]	eval-auc:0.80912	train-auc:1.00000
#
# [1134]	eval-auc:0.80912	train-auc:1.00000
#
# [1135]	eval-auc:0.80912	train-auc:1.00000
#
# [1136]	eval-auc:0.80912	train-auc:1.00000
#
# [1137]	eval-auc:0.80912	train-auc:1.00000
#
# [1138]	eval-auc:0.80912	train-auc:1.00000
#
# [1139]	eval-auc:0.80912	train-auc:1.00000
# [1140]	eval-auc:0.80912	train-auc:1.00000
#
# [1141]	eval-auc:0.80912	train-auc:1.00000
#
# [1142]	eval-auc:0.80912	train-auc:1.00000
#
# [1143]	eval-auc:0.80912	train-auc:1.00000
#
# [1144]	eval-auc:0.80912	train-auc:1.00000
#
# [1145]	eval-auc:0.80912	train-auc:1.00000
#
# [1146]	eval-auc:0.80912	train-auc:1.00000
#
# [1147]	eval-auc:0.80912	train-auc:1.00000
#
# [1148]	eval-auc:0.80912	train-auc:1.00000
#
# [1149]	eval-auc:0.80912	train-auc:1.00000
#
# [1150]	eval-auc:0.80912	train-auc:1.00000
#
# [1151]	eval-auc:0.80912	train-auc:1.00000
#
# [1152]	eval-auc:0.80912	train-auc:1.00000
#
# [1153]	eval-auc:0.80912	train-auc:1.00000
#
# [1154]	eval-auc:0.80912	train-auc:1.00000
#
# [1155]	eval-auc:0.80912	train-auc:1.00000
#
# [1156]	eval-auc:0.80912	train-auc:1.00000
#
# [1157]	eval-auc:0.80912	train-auc:1.00000
#
# [1158]	eval-auc:0.80912	train-auc:1.00000
#
# [1159]	eval-auc:0.80912	train-auc:1.00000
#
# [1160]	eval-auc:0.80912	train-auc:1.00000
#
# [1161]	eval-auc:0.80912	train-auc:1.00000
#
# [1162]	eval-auc:0.80912	train-auc:1.00000
#
# [1163]	eval-auc:0.80912	train-auc:1.00000
#
# [1164]	eval-auc:0.80984	train-auc:1.00000
#
# 	Score 0.753384912959381
#
#
# 100%|███████████████████████████████████████████████████| 3/3 [06:53<00:00, 137.96s/it, best loss: 0.24661508704061896]
# The best hyperparameters are:
#
# {'colsample_bylevel ': 0.305, 'colsample_bynode': 0.44, 'colsample_bytree': 0.325, 'eta': 0.525, 'gamma': 0.435, 'max_depth': 261, 'min_child_weight': 4.0, 'n_estimators': 615, 'reg_alpha': 0.114, 'reg_lambda': 0.489, 'subsample': 0.8300000000000001}

# %%
trials

# %%
best_hpy = {'colsample_bylevel ': 0.235, 'colsample_bynode': 0.075, 'colsample_bytree': 0.585, 'eta': 0.5, 'gamma': 0.44, 'max_depth': 260, 'min_child_weight': 4.0, 'n_estimators': 1200, 'reg_alpha': 0.12, 'reg_lambda': 0.5, 'subsample': 0.885,
            
            
            'eval_metric': 'auc',
        'objective': 'binary:logistic',
        # Increase this number if you have more cores. Otherwise, remove it and it will default 
        # to the maxium number. 
        
        'nthread': 7,
        'booster': 'gbtree',
        'tree_method': 'exact',
        'silent': 1}

# %%
clf = xgb.XGBClassifier(gpu_id=0, **best_hpy)

# %%
clf.fit(X_train, y_train, verbose=3)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bylevel =0.235, colsample_bynode=0.075,
#               colsample_bytree=0.585, eta=0.5, eval_metric='auc', gamma=0.44,
#               gpu_id=0, learning_rate=0.1, max_delta_step=0, max_depth=260,
#               min_child_weight=4.0, missing=None, n_estimators=1200, n_jobs=1,
#               nthread=7, objective='binary:logistic', random_state=0,
#               reg_alpha=0.12, reg_lambda=0.5, scale_pos_weight=1, silent=1,
#               subsample=0.885, tree_method='exact', verbosity=1)

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
clf.score(X_valid, y_valid)
# Out:
# 0.7637362637362637

# %%
from sklearn.metrics import classification_report, confusion_matrix

predIdxs = clf.predict(X_valid)
#predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(y_valid, predIdxs,
    target_names=validation_generator.class_indices.keys()))
# compute the confusion matrix and and use it to derive the raw accuracy, sensitivity, and specificity
cm = confusion_matrix(validation_generator.classes, predIdxs)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
# show the confusion matrix, accuracy, sensitivity, and specificity
print(cm)
print("acc: {:.4f}".format(acc))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-3f9b592c8cde> in <module>
#       3 predIdxs = clf.predict(X_valid)
#       4 #predIdxs = np.argmax(predIdxs, axis=1)
# ----> 5 print(classification_report(validation_generator.classes, predIdxs,
#       6     target_names=validation_generator.class_indices.keys()))
#       7 # compute the confusion matrix and and use it to derive the raw accuracy, sensitivity, and specificity
#
# NameError: name 'validation_generator' is not defined

# %%
sum(clf.feature_importances_[relev_features])/sum(clf.feature_importances_)

# %%
all_relev_features = clf.feature_importances_

# %%
relev_features = all_relev_features.argsort()[-708:][::-1]

# %%
relev_features

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
clf.fit(X_train, y_train)

# %%
clf.score(X_train, y_train)

# %%
clf.score(X_valid, y_valid)

# %%
clf.feature_importances_

# %%
len(np.where(clf.feature_importances_ == 0)[0])
