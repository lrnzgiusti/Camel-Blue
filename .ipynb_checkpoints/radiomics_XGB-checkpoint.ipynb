# %%
import xgboost as xgb
import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score, accuracy_score

# Hyperparameters tuning

from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %%
X_train_tumor = pd.read_csv(r"C:\Users\logiusti\Lorenzo\PyWorkspace\Camel-Blue\radiomics_train_tumor_feature.csv")
X_train_no_tumor = pd.read_csv(r"C:\Users\logiusti\Lorenzo\PyWorkspace\Camel-Blue\radiomics_train_no_tumor_feature.csv")

X_valid_tumor = pd.read_csv(r"C:\Users\logiusti\Lorenzo\PyWorkspace\Camel-Blue\radiomics_valid_tumor_feature.csv")
X_valid_no_tumor = pd.read_csv(r"C:\Users\logiusti\Lorenzo\PyWorkspace\Camel-Blue\radiomics_valid_no_tumor_feature.csv")

# %%
del X_train_tumor['Image_Name']
del X_train_no_tumor['Image_Name']
del X_valid_tumor['Image_Name']
del X_valid_no_tumor['Image_Name']

# %%
X_train = X_train_tumor.append(X_train_no_tumor, ignore_index=True).sample(frac=1)
X_valid = X_valid_tumor.append(X_valid_no_tumor, ignore_index=True)#.sample(frac=1)

# %%
y_train = X_train['Label'].to_numpy()
y_valid = X_valid['Label'].to_numpy()

del X_train['Label']
del X_valid['Label']

X_train = X_train.to_numpy()
X_valid = X_valid.to_numpy()

y_train = np.vectorize({'Tumor':1, 'No_Tumor':0}.get)(y_train)
y_valid = np.vectorize({'Tumor':1, 'No_Tumor':0}.get)(y_valid)

# %% [markdown]
# # Pick only the most relevant features N:20

# %%
X_train_backup = X_train
X_valid_backup = X_valid

# %%
X_train = X_train_backup
X_valid = X_valid_backup

# %%
X_train = X_train.transpose()[relev_features].transpose()
X_valid = X_valid.transpose()[relev_features].transpose()

# %%
X_train.shape
# Out:
# (1056, 708)

# %%
def score(params):
    print("Training with params: ")
    print(params)
    num_round = int(params['n_estimators'])
    del params['n_estimators']
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dvalid = xgb.DMatrix(X_valid, label=y_valid)
    watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
    gbm_model = xgb.train(params, dtrain, num_round,
                          evals=watchlist,
                          verbose_eval=True)
    predictions = gbm_model.predict(dvalid,
                                    ntree_limit=gbm_model.best_iteration + 1)
    score = roc_auc_score(y_valid, predictions.round())
    # TODO: Add the importance for the selected features
    print("\tScore {0}\n\n".format(score))
    # The score function should return the loss (1-score)
    # since the optimize function looks for the minimum
    loss = 1 - score
    return {'loss': loss, 'status': STATUS_OK}


def optimize(
             #trials, 
             random_state=1234):
    """
    This is the optimization function that given a space (space here) of 
    hyperparameters and a scoring function (score here), finds the best hyperparameters.
    """
    # To learn more about XGBoost parameters, head to this page: 
    # https://github.com/dmlc/xgboost/blob/master/doc/parameter.md
    space = {
        'n_estimators': hp.choice('n_estimators', np.arange(550, 2500, dtype=int)),
        'eta': hp.quniform('eta', 0.15, 1, 0.025),
        # A problem with max_depth casted to float instead of int with
        # the hp.quniform method.
        'max_depth':  hp.choice('max_depth', np.arange(1, 250, dtype=int)),
        'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),
        'subsample': hp.quniform('subsample', 0, 1, 0.005),
        'gamma': hp.quniform('gamma', 0, 1, 0.005),
        'colsample_bytree': hp.quniform('colsample_bytree', 0, 1, 0.005),
        'colsample_bylevel ': hp.quniform('colsample_bylevel ', 0, 1, 0.005),
        'colsample_bynode': hp.quniform('colsample_bynode', 0, 1, 0.005),
        'reg_alpha' : hp.quniform('reg_alpha', 0.003, 1, 0.003),
        'reg_lambda' : hp.quniform('reg_lambda', 0.003, 1, 0.003),
        'eval_metric': 'auc',
        'objective': 'binary:logistic',
        # Increase this number if you have more cores. Otherwise, remove it and it will default 
        # to the maxium number. 
        'nthread': 7,
        'booster': 'gbtree',
        'tree_method': 'gpu_hist',
        'silent': 1,
        'seed': random_state
    }
    # Use the fmin function from Hyperopt to find the best hyperparameters
    trials = Trials()
    best = fmin(score, space, algo=tpe.suggest, 
                trials=trials,
               max_evals=3)
    return best



best_hyperparams = optimize(
                            #trials
                            )
print("The best hyperparameters are: ", "\n")
print(best_hyperparams)
# Out:
# Training with params:
# {'booster': 'gbtree', 'colsample_bylevel ': 0.92, 'colsample_bynode': 0.885, 'colsample_bytree': 0.99, 'eta': 0.2, 'eval_metric': 'auc', 'gamma': 1.0, 'max_depth': 19, 'min_child_weight': 3.0, 'n_estimators': 1483, 'nthread': 7, 'objective': 'binary:logistic', 'reg_alpha': 0.066, 'reg_lambda': 0.8250000000000001, 'seed': 1234, 'silent': 1, 'subsample': 0.075, 'tree_method': 'gpu_hist'}
# [0]	eval-auc:0.53427	train-auc:0.58255
#
# [1]	eval-auc:0.66465	train-auc:0.66550
#
# [2]	eval-auc:0.71778	train-auc:0.72138
#
# [3]	eval-auc:0.71083	train-auc:0.73513
#
# [4]	eval-auc:0.73543	train-auc:0.74934
#
# [5]	eval-auc:0.74293	train-auc:0.75667
#
# [6]	eval-auc:0.75393	train-auc:0.76117
#
# [7]	eval-auc:0.76257	train-auc:0.76237
#
# [8]	eval-auc:0.73852	train-auc:0.78716
#
# [9]	eval-auc:0.76378	train-auc:0.78698
#
# [10]	eval-auc:0.77962	train-auc:0.79619
#
# [11]	eval-auc:0.76336	train-auc:0.79858
#
# [12]	eval-auc:0.78784	train-auc:0.80973
#
# [13]	eval-auc:0.79497	train-auc:0.81032
#
# [14]	eval-auc:0.81093	train-auc:0.81676
#
# [15]	eval-auc:0.81359	train-auc:0.81764
#
# [16]	eval-auc:0.81371	train-auc:0.82144
#
# [17]	eval-auc:0.79956	train-auc:0.82200
#
# [18]	eval-auc:0.79618	train-auc:0.82350
#
# [19]	eval-auc:0.79364	train-auc:0.83123
#
# [20]	eval-auc:0.78058	train-auc:0.82763
#
# [21]	eval-auc:0.77974	train-auc:0.83676
#
# [22]	eval-auc:0.76342	train-auc:0.83837
#
# [23]	eval-auc:0.77224	train-auc:0.83732
#
# [24]	eval-auc:0.77236	train-auc:0.83544
#
# [25]	eval-auc:0.77672	train-auc:0.83974
#
# [26]	eval-auc:0.75858	train-auc:0.83911
#
# [27]	eval-auc:0.78058	train-auc:0.83898
#
# [28]	eval-auc:0.77926	train-auc:0.83669
#
# [29]	eval-auc:0.78796	train-auc:0.83878
#
# [30]	eval-auc:0.78192	train-auc:0.84236
#
# [31]	eval-auc:0.78663	train-auc:0.84293
#
# [32]	eval-auc:0.78385	train-auc:0.84176
#
# [33]	eval-auc:0.80259	train-auc:0.84295
#
# [34]	eval-auc:0.80742	train-auc:0.84527
#
# [35]	eval-auc:0.80150	train-auc:0.84628
#
# [36]	eval-auc:0.79412	train-auc:0.84771
#
# [37]	eval-auc:0.78615	train-auc:0.84789
#
# [38]	eval-auc:0.78941	train-auc:0.84742
#
# [39]	eval-auc:0.78155	train-auc:0.84788
#
# [40]	eval-auc:0.77599	train-auc:0.84674
#
# [41]	eval-auc:0.77768	train-auc:0.84478
#
# [42]	eval-auc:0.79243	train-auc:0.84721
#
# [43]	eval-auc:0.79944	train-auc:0.85028
#
# [44]	eval-auc:0.79969	train-auc:0.85016
#
# [45]	eval-auc:0.78578	train-auc:0.84936
#
# [46]	eval-auc:0.78881	train-auc:0.85245
#
# [47]	eval-auc:0.78953	train-auc:0.84919
#
# [48]	eval-auc:0.79171	train-auc:0.84999
#
# [49]	eval-auc:0.78204	train-auc:0.85048
#
# [50]	eval-auc:0.78409	train-auc:0.85259
#
# [51]	eval-auc:0.78083	train-auc:0.85205
#
# [52]	eval-auc:0.78337	train-auc:0.85145
#
# [53]	eval-auc:0.78107	train-auc:0.85294
#
# [54]	eval-auc:0.78240	train-auc:0.85377
#
# [55]	eval-auc:0.77539	train-auc:0.85428
#
# [56]	eval-auc:0.76789	train-auc:0.85274
#
# [57]	eval-auc:0.76656	train-auc:0.85353
#
# [58]	eval-auc:0.77539	train-auc:0.85479
#
# [59]	eval-auc:0.76886	train-auc:0.85476
#
# [60]	eval-auc:0.77926	train-auc:0.85856
#
# [61]	eval-auc:0.77007	train-auc:0.85967
#
# [62]	eval-auc:0.77369	train-auc:0.86211
# [63]	eval-auc:0.77986	train-auc:0.86250
#
# [64]	eval-auc:0.78216	train-auc:0.86560
#
# [65]	eval-auc:0.78179	train-auc:0.86483
#
# [66]	eval-auc:0.77514	train-auc:0.86510
#
# [67]	eval-auc:0.78421	train-auc:0.86547
#
# [68]	eval-auc:0.78058	train-auc:0.86615
#
# [69]	eval-auc:0.77152	train-auc:0.86640
#
# [70]	eval-auc:0.76765	train-auc:0.86823
#
# [71]	eval-auc:0.76680	train-auc:0.86624
#
# [72]	eval-auc:0.76729	train-auc:0.86884
#
# [73]	eval-auc:0.76475	train-auc:0.86901
#
# [74]	eval-auc:0.76704	train-auc:0.87077
#
# [75]	eval-auc:0.78022	train-auc:0.87250
#
# [76]	eval-auc:0.77853	train-auc:0.87072
#
# [77]	eval-auc:0.78107	train-auc:0.87281
#
# [78]	eval-auc:0.77865	train-auc:0.87738
#
# [79]	eval-auc:0.77926	train-auc:0.87845
#
# [80]	eval-auc:0.78252	train-auc:0.87868
#
# [81]	eval-auc:0.78107	train-auc:0.88004
#
# [82]	eval-auc:0.78651	train-auc:0.88056
#
# [83]	eval-auc:0.78192	train-auc:0.88090
#
# [84]	eval-auc:0.77913	train-auc:0.88152
#
# [85]	eval-auc:0.76874	train-auc:0.88052
#
# [86]	eval-auc:0.78627	train-auc:0.88090
#
# [87]	eval-auc:0.78046	train-auc:0.88072
#
# [88]	eval-auc:0.78784	train-auc:0.88206
#
# [89]	eval-auc:0.78252	train-auc:0.88145
#
# [90]	eval-auc:0.78518	train-auc:0.88233
#
# [91]	eval-auc:0.78071	train-auc:0.88313
#
# [92]	eval-auc:0.77672	train-auc:0.88419
#
# [93]	eval-auc:0.77079	train-auc:0.88440
#
# [94]	eval-auc:0.77672	train-auc:0.88428
#
# [95]	eval-auc:0.77865	train-auc:0.88268
#
# [96]	eval-auc:0.78058	train-auc:0.88273
#
# [97]	eval-auc:0.79110	train-auc:0.88224
#
# [98]	eval-auc:0.78300	train-auc:0.88286
#
# [99]	eval-auc:0.78071	train-auc:0.88309
#
# [100]	eval-auc:0.78433	train-auc:0.88470
#
# [101]	eval-auc:0.78349	train-auc:0.88662
#
# [102]	eval-auc:0.78590	train-auc:0.88486
#
# [103]	eval-auc:0.79038	train-auc:0.88617
#
# [104]	eval-auc:0.78639	train-auc:0.88523
#
# [105]	eval-auc:0.78651	train-auc:0.88430
#
# [106]	eval-auc:0.78772	train-auc:0.88596
#
# [107]	eval-auc:0.77974	train-auc:0.88771
#
# [108]	eval-auc:0.76983	train-auc:0.88888
#
# [109]	eval-auc:0.77442	train-auc:0.88811
#
# [110]	eval-auc:0.77188	train-auc:0.88891
#
# [111]	eval-auc:0.78240	train-auc:0.88811
#
# [112]	eval-auc:0.77998	train-auc:0.88704
#
# [113]	eval-auc:0.78107	train-auc:0.88953
#
# [114]	eval-auc:0.77829	train-auc:0.88985
#
# [115]	eval-auc:0.77913	train-auc:0.89144
#
# [116]	eval-auc:0.77248	train-auc:0.89068
#
# [117]	eval-auc:0.77091	train-auc:0.89024
#
# [118]	eval-auc:0.75701	train-auc:0.89134
#
# [119]	eval-auc:0.75338	train-auc:0.89085
#
# [120]	eval-auc:0.75786	train-auc:0.89054
#
# [121]	eval-auc:0.75991	train-auc:0.89091
#
# [122]	eval-auc:0.74964	train-auc:0.89116
#
# [123]	eval-auc:0.75048	train-auc:0.89013
#
# [124]	eval-auc:0.75641	train-auc:0.89087
#
# [125]	eval-auc:0.76185	train-auc:0.88814
#
# [126]	eval-auc:0.76620	train-auc:0.88859
#
# [127]	eval-auc:0.76487	train-auc:0.88812
#
# [128]	eval-auc:0.76668	train-auc:0.88798
#
# [129]	eval-auc:0.76245	train-auc:0.88970
# [130]	eval-auc:0.76620	train-auc:0.89006
#
# [131]	eval-auc:0.76475	train-auc:0.89134
#
# [132]	eval-auc:0.76016	train-auc:0.89024
#
# [133]	eval-auc:0.75870	train-auc:0.88874
#
# [134]	eval-auc:0.75338	train-auc:0.88993
#
# [135]	eval-auc:0.76003	train-auc:0.89086
#
# [136]	eval-auc:0.76245	train-auc:0.89297
#
# [137]	eval-auc:0.76487	train-auc:0.89389
#
# [138]	eval-auc:0.75895	train-auc:0.89466
#
# [139]	eval-auc:0.75363	train-auc:0.89334
#
# [140]	eval-auc:0.75762	train-auc:0.89280
#
# [141]	eval-auc:0.74928	train-auc:0.89254
#
# [142]	eval-auc:0.75774	train-auc:0.89448
#
# [143]	eval-auc:0.75907	train-auc:0.89379
#
# [144]	eval-auc:0.76487	train-auc:0.89456
#
# [145]	eval-auc:0.76656	train-auc:0.89591
#
# [146]	eval-auc:0.76596	train-auc:0.89404
#
# [147]	eval-auc:0.77019	train-auc:0.89295
#
# [148]	eval-auc:0.76487	train-auc:0.89305
#
# [149]	eval-auc:0.75230	train-auc:0.89410
#
# [150]	eval-auc:0.75895	train-auc:0.89485
#
# [151]	eval-auc:0.75907	train-auc:0.89375
#
# [152]	eval-auc:0.76112	train-auc:0.89392
#
# [153]	eval-auc:0.76414	train-auc:0.89354
#
# [154]	eval-auc:0.75109	train-auc:0.89152
#
# [155]	eval-auc:0.74698	train-auc:0.89172
#
# [156]	eval-auc:0.73489	train-auc:0.88987
#
# [157]	eval-auc:0.72788	train-auc:0.89043
#
# [158]	eval-auc:0.72812	train-auc:0.88913
#
# [159]	eval-auc:0.73187	train-auc:0.88999
#
# [160]	eval-auc:0.73211	train-auc:0.89021
#
# [161]	eval-auc:0.73138	train-auc:0.89229
#
# [162]	eval-auc:0.74250	train-auc:0.89303
#
# [163]	eval-auc:0.73972	train-auc:0.89024
#
# [164]	eval-auc:0.74299	train-auc:0.88899
#
# [165]	eval-auc:0.74613	train-auc:0.88993
#
# [166]	eval-auc:0.74758	train-auc:0.88932
#
# [167]	eval-auc:0.74565	train-auc:0.88861
#
# [168]	eval-auc:0.74565	train-auc:0.89116
#
# [169]	eval-auc:0.74565	train-auc:0.89325
#
# [170]	eval-auc:0.74287	train-auc:0.89235
#
# [171]	eval-auc:0.74468	train-auc:0.89546
#
# [172]	eval-auc:0.75072	train-auc:0.89527
#
# [173]	eval-auc:0.75109	train-auc:0.89611
#
# [174]	eval-auc:0.75012	train-auc:0.89609
#
# [175]	eval-auc:0.75000	train-auc:0.89678
#
# [176]	eval-auc:0.73791	train-auc:0.89599
#
# [177]	eval-auc:0.73864	train-auc:0.89567
#
# [178]	eval-auc:0.73912	train-auc:0.89738
#
# [179]	eval-auc:0.74565	train-auc:0.89961
#
# [180]	eval-auc:0.74420	train-auc:0.89927
#
# [181]	eval-auc:0.74359	train-auc:0.89905
#
# [182]	eval-auc:0.74420	train-auc:0.89727
#
# [183]	eval-auc:0.74456	train-auc:0.89690
#
# [184]	eval-auc:0.74855	train-auc:0.89744
#
# [185]	eval-auc:0.74528	train-auc:0.89858
#
# [186]	eval-auc:0.74323	train-auc:0.89961
#
# [187]	eval-auc:0.74323	train-auc:0.90193
#
# [188]	eval-auc:0.74492	train-auc:0.90082
#
# [189]	eval-auc:0.74782	train-auc:0.90014
#
# [190]	eval-auc:0.74456	train-auc:0.89900
#
# [191]	eval-auc:0.74758	train-auc:0.89820
#
# [192]	eval-auc:0.74734	train-auc:0.89885
#
# [193]	eval-auc:0.75351	train-auc:0.89835
#
# [194]	eval-auc:0.75991	train-auc:0.89839
#
# [195]	eval-auc:0.76148	train-auc:0.89791
#
# [196]	eval-auc:0.75907	train-auc:0.89988
# [197]	eval-auc:0.76318	train-auc:0.89896
#
# [198]	eval-auc:0.76016	train-auc:0.90009
#
# [199]	eval-auc:0.76439	train-auc:0.89912
#
# [200]	eval-auc:0.76777	train-auc:0.89860
#
# [201]	eval-auc:0.77261	train-auc:0.89875
#
# [202]	eval-auc:0.77067	train-auc:0.89802
#
# [203]	eval-auc:0.76572	train-auc:0.89886
#
# [204]	eval-auc:0.76547	train-auc:0.89880
#
# [205]	eval-auc:0.76052	train-auc:0.89936
#
# [206]	eval-auc:0.74674	train-auc:0.89880
#
# [207]	eval-auc:0.74722	train-auc:0.89927
#
# [208]	eval-auc:0.75689	train-auc:0.90025
#
# [209]	eval-auc:0.75580	train-auc:0.90223
#
# [210]	eval-auc:0.75701	train-auc:0.90138
#
# [211]	eval-auc:0.76451	train-auc:0.90132
#
# [212]	eval-auc:0.76064	train-auc:0.90281
#
# [213]	eval-auc:0.76052	train-auc:0.90270
#
# [214]	eval-auc:0.75580	train-auc:0.90322
#
# [215]	eval-auc:0.75048	train-auc:0.90317
#
# [216]	eval-auc:0.75085	train-auc:0.90317
#
# [217]	eval-auc:0.74794	train-auc:0.90327
#
# [218]	eval-auc:0.75133	train-auc:0.90221
#
# [219]	eval-auc:0.74807	train-auc:0.90231
#
# [220]	eval-auc:0.73791	train-auc:0.90230
#
# [221]	eval-auc:0.73308	train-auc:0.90334
#
# [222]	eval-auc:0.73392	train-auc:0.90299
#
# [223]	eval-auc:0.73755	train-auc:0.90381
#
# [224]	eval-auc:0.73259	train-auc:0.90383
#
# [225]	eval-auc:0.74093	train-auc:0.90617
#
# [226]	eval-auc:0.73936	train-auc:0.90644
#
# [227]	eval-auc:0.73731	train-auc:0.90609
#
# [228]	eval-auc:0.74674	train-auc:0.90728
#
# [229]	eval-auc:0.73622	train-auc:0.90675
#
# [230]	eval-auc:0.73972	train-auc:0.90699
#
# [231]	eval-auc:0.73997	train-auc:0.90701
#
# [232]	eval-auc:0.73924	train-auc:0.90760
#
# [233]	eval-auc:0.72703	train-auc:0.90636
#
# [234]	eval-auc:0.73344	train-auc:0.90685
#
# [235]	eval-auc:0.73694	train-auc:0.90793
#
# [236]	eval-auc:0.74105	train-auc:0.90610
#
# [237]	eval-auc:0.75048	train-auc:0.90770
#
# [238]	eval-auc:0.75520	train-auc:0.90850
#
# [239]	eval-auc:0.75097	train-auc:0.90953
#
# [240]	eval-auc:0.74758	train-auc:0.90851
#
# [241]	eval-auc:0.73368	train-auc:0.90937
#
# [242]	eval-auc:0.73513	train-auc:0.90938
#
# [243]	eval-auc:0.73815	train-auc:0.91031
#
# [244]	eval-auc:0.72909	train-auc:0.90995
#
# [245]	eval-auc:0.73622	train-auc:0.91036
#
# [246]	eval-auc:0.73827	train-auc:0.90981
#
# [247]	eval-auc:0.73610	train-auc:0.91117
#
# [248]	eval-auc:0.73513	train-auc:0.91161
#
# [249]	eval-auc:0.73574	train-auc:0.91228
#
# [250]	eval-auc:0.73719	train-auc:0.91118
#
# [251]	eval-auc:0.73392	train-auc:0.91263
#
# [252]	eval-auc:0.73247	train-auc:0.91291
#
# [253]	eval-auc:0.74033	train-auc:0.91159
#
# [254]	eval-auc:0.73767	train-auc:0.91313
#
# [255]	eval-auc:0.73924	train-auc:0.91542
#
# [256]	eval-auc:0.73658	train-auc:0.91490
#
# [257]	eval-auc:0.72921	train-auc:0.91341
#
# [258]	eval-auc:0.72969	train-auc:0.91475
#
# [259]	eval-auc:0.73428	train-auc:0.91614
#
# [260]	eval-auc:0.73574	train-auc:0.91747
#
# [261]	eval-auc:0.73598	train-auc:0.91837
#
# [262]	eval-auc:0.73694	train-auc:0.91971
#
# [263]	eval-auc:0.72437	train-auc:0.91908
# [264]	eval-auc:0.72570	train-auc:0.92053
#
# [265]	eval-auc:0.71833	train-auc:0.92000
#
# [266]	eval-auc:0.72800	train-auc:0.92134
#
# [267]	eval-auc:0.72691	train-auc:0.92080
#
# [268]	eval-auc:0.72437	train-auc:0.91946
#
# [269]	eval-auc:0.73042	train-auc:0.92027
#
# [270]	eval-auc:0.73815	train-auc:0.92081
#
# [271]	eval-auc:0.73731	train-auc:0.92007
#
# [272]	eval-auc:0.73682	train-auc:0.92137
#
# [273]	eval-auc:0.73924	train-auc:0.92107
#
# [274]	eval-auc:0.73561	train-auc:0.91944
#
# [275]	eval-auc:0.73840	train-auc:0.92010
#
# [276]	eval-auc:0.74214	train-auc:0.91931
#
# [277]	eval-auc:0.74879	train-auc:0.91828
#
# [278]	eval-auc:0.74250	train-auc:0.91890
#
# [279]	eval-auc:0.73561	train-auc:0.91888
#
# [280]	eval-auc:0.73296	train-auc:0.91936
#
# [281]	eval-auc:0.73066	train-auc:0.91904
#
# [282]	eval-auc:0.72752	train-auc:0.91955
#
# [283]	eval-auc:0.71398	train-auc:0.91755
#
# [284]	eval-auc:0.71627	train-auc:0.92006
#
# [285]	eval-auc:0.72111	train-auc:0.91857
#
# [286]	eval-auc:0.72449	train-auc:0.91854
#
# [287]	eval-auc:0.72752	train-auc:0.91793
#
# [288]	eval-auc:0.72570	train-auc:0.91694
#
# [289]	eval-auc:0.71712	train-auc:0.91525
#
# [290]	eval-auc:0.71252	train-auc:0.91369
#
# [291]	eval-auc:0.73042	train-auc:0.91558
#
# [292]	eval-auc:0.72486	train-auc:0.91683
#
# [293]	eval-auc:0.72062	train-auc:0.91643
#
# [294]	eval-auc:0.72256	train-auc:0.91706
#
# [295]	eval-auc:0.71458	train-auc:0.91609
#
# [296]	eval-auc:0.71144	train-auc:0.91605
#
# [297]	eval-auc:0.71724	train-auc:0.91692
#
# [298]	eval-auc:0.71228	train-auc:0.91639
#
# [299]	eval-auc:0.72316	train-auc:0.91646
#
# [300]	eval-auc:0.72727	train-auc:0.91590
#
# [301]	eval-auc:0.73779	train-auc:0.91614
#
# [302]	eval-auc:0.73489	train-auc:0.91487
#
# [303]	eval-auc:0.72594	train-auc:0.91456
#
# [304]	eval-auc:0.72365	train-auc:0.91282
#
# [305]	eval-auc:0.72727	train-auc:0.91533
#
# [306]	eval-auc:0.72643	train-auc:0.91482
#
# [307]	eval-auc:0.73344	train-auc:0.91556
#
# [308]	eval-auc:0.73779	train-auc:0.91570
#
# [309]	eval-auc:0.74033	train-auc:0.91509
#
# [310]	eval-auc:0.74118	train-auc:0.91528
#
# [311]	eval-auc:0.75012	train-auc:0.91651
#
# [312]	eval-auc:0.74359	train-auc:0.91713
#
# [313]	eval-auc:0.75036	train-auc:0.91915
#
# [314]	eval-auc:0.74226	train-auc:0.92009
#
# [315]	eval-auc:0.74492	train-auc:0.92047
#
# [316]	eval-auc:0.75024	train-auc:0.92153
#
# [317]	eval-auc:0.74964	train-auc:0.92154
#
# [318]	eval-auc:0.75314	train-auc:0.92184
#
# [319]	eval-auc:0.75097	train-auc:0.92177
#
# [320]	eval-auc:0.75532	train-auc:0.92275
#
# [321]	eval-auc:0.75919	train-auc:0.92291
#
# [322]	eval-auc:0.75484	train-auc:0.92290
#
# [323]	eval-auc:0.75169	train-auc:0.92265
#
# [324]	eval-auc:0.75931	train-auc:0.92353
#
# [325]	eval-auc:0.76209	train-auc:0.92310
#
# [326]	eval-auc:0.76112	train-auc:0.92288
#
# [327]	eval-auc:0.76197	train-auc:0.92312
#
# [328]	eval-auc:0.76608	train-auc:0.92389
#
# [329]	eval-auc:0.76596	train-auc:0.92369
#
# [330]	eval-auc:0.76451	train-auc:0.92492
# [331]	eval-auc:0.77140	train-auc:0.92399
#
# [332]	eval-auc:0.77116	train-auc:0.92351
#
# [333]	eval-auc:0.76765	train-auc:0.92242
#
# [334]	eval-auc:0.76765	train-auc:0.92242
#
# [335]	eval-auc:0.75895	train-auc:0.92204
#
# [336]	eval-auc:0.76777	train-auc:0.92258
#
# [337]	eval-auc:0.76439	train-auc:0.92300
#
# [338]	eval-auc:0.76257	train-auc:0.92308
#
# [339]	eval-auc:0.76584	train-auc:0.92415
#
# [340]	eval-auc:0.76656	train-auc:0.92363
#
# [341]	eval-auc:0.76511	train-auc:0.92409
#
# [342]	eval-auc:0.76753	train-auc:0.92503
#
# [343]	eval-auc:0.76209	train-auc:0.92432
#
# [344]	eval-auc:0.76922	train-auc:0.92415
#
# [345]	eval-auc:0.76729	train-auc:0.92589
#
# [346]	eval-auc:0.76160	train-auc:0.92646
#
# [347]	eval-auc:0.76560	train-auc:0.92789
#
# [348]	eval-auc:0.76511	train-auc:0.92806
#
# [349]	eval-auc:0.76052	train-auc:0.92693
#
# [350]	eval-auc:0.76052	train-auc:0.92693
#
# [351]	eval-auc:0.76028	train-auc:0.92915
#
# [352]	eval-auc:0.75895	train-auc:0.92947
#
# [353]	eval-auc:0.75580	train-auc:0.92872
#
# [354]	eval-auc:0.75375	train-auc:0.92815
#
# [355]	eval-auc:0.75459	train-auc:0.92924
#
# [356]	eval-auc:0.75713	train-auc:0.92982
#
# [357]	eval-auc:0.76221	train-auc:0.93061
#
# [358]	eval-auc:0.76704	train-auc:0.93115
#
# [359]	eval-auc:0.76547	train-auc:0.92998
#
# [360]	eval-auc:0.76692	train-auc:0.93169
#
# [361]	eval-auc:0.76064	train-auc:0.93322
#
# [362]	eval-auc:0.76124	train-auc:0.93359
#
# [363]	eval-auc:0.74976	train-auc:0.93360
#
# [364]	eval-auc:0.75713	train-auc:0.93427
#
# [365]	eval-auc:0.75713	train-auc:0.93427
#
# [366]	eval-auc:0.75750	train-auc:0.93463
#
# [367]	eval-auc:0.75544	train-auc:0.93517
#
# [368]	eval-auc:0.76281	train-auc:0.93529
#
# [369]	eval-auc:0.76995	train-auc:0.93497
#
# [370]	eval-auc:0.76306	train-auc:0.93461
#
# [371]	eval-auc:0.76306	train-auc:0.93461
#
# [372]	eval-auc:0.76124	train-auc:0.93483
#
# [373]	eval-auc:0.76112	train-auc:0.93642
#
# [374]	eval-auc:0.76064	train-auc:0.93656
#
# [375]	eval-auc:0.76451	train-auc:0.93698
#
# [376]	eval-auc:0.76439	train-auc:0.93656
#
# [377]	eval-auc:0.76221	train-auc:0.93580
#
# [378]	eval-auc:0.77188	train-auc:0.93483
#
# [379]	eval-auc:0.76668	train-auc:0.93586
#
# [380]	eval-auc:0.76342	train-auc:0.93492
#
# [381]	eval-auc:0.76040	train-auc:0.93393
#
# [382]	eval-auc:0.76185	train-auc:0.93327
#
# [383]	eval-auc:0.76572	train-auc:0.93235
#
# [384]	eval-auc:0.77140	train-auc:0.93217
#
# [385]	eval-auc:0.77672	train-auc:0.93224
#
# [386]	eval-auc:0.77950	train-auc:0.93269
#
# [387]	eval-auc:0.77527	train-auc:0.93337
#
# [388]	eval-auc:0.77998	train-auc:0.93302
#
# [389]	eval-auc:0.77986	train-auc:0.93403
#
# [390]	eval-auc:0.77962	train-auc:0.93502
#
# [391]	eval-auc:0.77841	train-auc:0.93531
#
# [392]	eval-auc:0.78083	train-auc:0.93523
#
# [393]	eval-auc:0.78518	train-auc:0.93513
#
# [394]	eval-auc:0.78518	train-auc:0.93513
#
# ...
#
# [1490]	eval-auc:0.81794	train-auc:1.00000
#
# [1491]	eval-auc:0.81794	train-auc:1.00000
#
# [1492]	eval-auc:0.81794	train-auc:1.00000
#
# [1493]	eval-auc:0.81794	train-auc:1.00000
#
# [1494]	eval-auc:0.81794	train-auc:1.00000
#
# [1495]	eval-auc:0.81794	train-auc:1.00000
#
# [1496]	eval-auc:0.81794	train-auc:1.00000
#
# [1497]	eval-auc:0.81794	train-auc:1.00000
#
# [1498]	eval-auc:0.81794	train-auc:1.00000
#
# [1499]	eval-auc:0.81794	train-auc:1.00000
#
# [1500]	eval-auc:0.81794	train-auc:1.00000
#
# [1501]	eval-auc:0.81794	train-auc:1.00000
#
# [1502]	eval-auc:0.81806	train-auc:1.00000
#
# [1503]	eval-auc:0.81806	train-auc:1.00000
#
# [1504]	eval-auc:0.81806	train-auc:1.00000
#
# [1505]	eval-auc:0.81806	train-auc:1.00000
#
# [1506]	eval-auc:0.81842	train-auc:1.00000
#
# [1507]	eval-auc:0.81818	train-auc:1.00000
#
# [1508]	eval-auc:0.81818	train-auc:1.00000
#
# [1509]	eval-auc:0.81818	train-auc:1.00000
#
# [1510]	eval-auc:0.81818	train-auc:1.00000
#
# [1511]	eval-auc:0.81818	train-auc:1.00000
#
# [1512]	eval-auc:0.81830	train-auc:1.00000
#
# [1513]	eval-auc:0.81830	train-auc:1.00000
#
# [1514]	eval-auc:0.81830	train-auc:1.00000
#
# [1515]	eval-auc:0.81830	train-auc:1.00000
#
# [1516]	eval-auc:0.81830	train-auc:1.00000
#
# [1517]	eval-auc:0.81830	train-auc:1.00000
#
# [1518]	eval-auc:0.81830	train-auc:1.00000
#
# [1519]	eval-auc:0.81830	train-auc:1.00000
#
# [1520]	eval-auc:0.81830	train-auc:1.00000
#
# [1521]	eval-auc:0.81830	train-auc:1.00000
#
# [1522]	eval-auc:0.81830	train-auc:1.00000
#
# [1523]	eval-auc:0.81830	train-auc:1.00000
#
# [1524]	eval-auc:0.81842	train-auc:1.00000
#
# [1525]	eval-auc:0.81842	train-auc:1.00000
#
# [1526]	eval-auc:0.81842	train-auc:1.00000
#
# [1527]	eval-auc:0.81842	train-auc:1.00000
#
# [1528]	eval-auc:0.81842	train-auc:1.00000
#
# [1529]	eval-auc:0.81842	train-auc:1.00000
#
# [1530]	eval-auc:0.81842	train-auc:1.00000
#
# [1531]	eval-auc:0.81842	train-auc:1.00000
#
# [1532]	eval-auc:0.81842	train-auc:1.00000
#
# [1533]	eval-auc:0.81842	train-auc:1.00000
#
# [1534]	eval-auc:0.81842	train-auc:1.00000
#
# [1535]	eval-auc:0.81842	train-auc:1.00000
#
# [1536]	eval-auc:0.81842	train-auc:1.00000
#
# [1537]	eval-auc:0.81842	train-auc:1.00000
#
# [1538]	eval-auc:0.81842	train-auc:1.00000
#
# [1539]	eval-auc:0.81842	train-auc:1.00000
#
# [1540]	eval-auc:0.81842	train-auc:1.00000
#
# [1541]	eval-auc:0.81842	train-auc:1.00000
#
# [1542]	eval-auc:0.81842	train-auc:1.00000
#
# [1543]	eval-auc:0.81842	train-auc:1.00000
#
# [1544]	eval-auc:0.81842	train-auc:1.00000
#
# [1545]	eval-auc:0.81842	train-auc:1.00000
#
# [1546]	eval-auc:0.81842	train-auc:1.00000
#
# [1547]	eval-auc:0.81842	train-auc:1.00000
#
# [1548]	eval-auc:0.81866	train-auc:1.00000
#
# [1549]	eval-auc:0.81879	train-auc:1.00000
# [1550]	eval-auc:0.81879	train-auc:1.00000
#
# [1551]	eval-auc:0.81879	train-auc:1.00000
#
# [1552]	eval-auc:0.81866	train-auc:1.00000
#
# [1553]	eval-auc:0.81866	train-auc:1.00000
#
# [1554]	eval-auc:0.81866	train-auc:1.00000
#
# [1555]	eval-auc:0.81866	train-auc:1.00000
#
# [1556]	eval-auc:0.81866	train-auc:1.00000
#
# [1557]	eval-auc:0.81866	train-auc:1.00000
#
# [1558]	eval-auc:0.81866	train-auc:1.00000
#
# [1559]	eval-auc:0.81866	train-auc:1.00000
#
# [1560]	eval-auc:0.81866	train-auc:1.00000
#
# [1561]	eval-auc:0.81866	train-auc:1.00000
#
# [1562]	eval-auc:0.81866	train-auc:1.00000
#
# [1563]	eval-auc:0.81891	train-auc:1.00000
#
# [1564]	eval-auc:0.81891	train-auc:1.00000
#
# [1565]	eval-auc:0.81891	train-auc:1.00000
#
# [1566]	eval-auc:0.81891	train-auc:1.00000
#
# [1567]	eval-auc:0.81891	train-auc:1.00000
#
# [1568]	eval-auc:0.81891	train-auc:1.00000
#
# [1569]	eval-auc:0.81891	train-auc:1.00000
#
# [1570]	eval-auc:0.81891	train-auc:1.00000
#
# [1571]	eval-auc:0.81891	train-auc:1.00000
#
# [1572]	eval-auc:0.81891	train-auc:1.00000
#
# [1573]	eval-auc:0.81891	train-auc:1.00000
#
# [1574]	eval-auc:0.81891	train-auc:1.00000
#
# [1575]	eval-auc:0.81891	train-auc:1.00000
#
# [1576]	eval-auc:0.81854	train-auc:1.00000
#
# [1577]	eval-auc:0.81854	train-auc:1.00000
#
# [1578]	eval-auc:0.81866	train-auc:1.00000
#
# [1579]	eval-auc:0.81854	train-auc:1.00000
#
# [1580]	eval-auc:0.81854	train-auc:1.00000
#
# [1581]	eval-auc:0.81854	train-auc:1.00000
#
# [1582]	eval-auc:0.81854	train-auc:1.00000
#
# [1583]	eval-auc:0.81854	train-auc:1.00000
#
# [1584]	eval-auc:0.81854	train-auc:1.00000
#
# [1585]	eval-auc:0.81854	train-auc:1.00000
#
# [1586]	eval-auc:0.81866	train-auc:1.00000
#
# [1587]	eval-auc:0.81866	train-auc:1.00000
#
# [1588]	eval-auc:0.81866	train-auc:1.00000
#
# [1589]	eval-auc:0.81866	train-auc:1.00000
#
# [1590]	eval-auc:0.81866	train-auc:1.00000
#
# [1591]	eval-auc:0.81879	train-auc:1.00000
#
# [1592]	eval-auc:0.81879	train-auc:1.00000
#
# [1593]	eval-auc:0.81879	train-auc:1.00000
#
# [1594]	eval-auc:0.81830	train-auc:1.00000
#
# [1595]	eval-auc:0.81830	train-auc:1.00000
#
# [1596]	eval-auc:0.81842	train-auc:1.00000
#
# [1597]	eval-auc:0.81842	train-auc:1.00000
#
# [1598]	eval-auc:0.81842	train-auc:1.00000
#
# [1599]	eval-auc:0.81842	train-auc:1.00000
#
# [1600]	eval-auc:0.81842	train-auc:1.00000
#
# [1601]	eval-auc:0.81842	train-auc:1.00000
#
# [1602]	eval-auc:0.81842	train-auc:1.00000
#
# [1603]	eval-auc:0.81879	train-auc:1.00000
#
# [1604]	eval-auc:0.81854	train-auc:1.00000
#
# [1605]	eval-auc:0.81854	train-auc:1.00000
#
# [1606]	eval-auc:0.81854	train-auc:1.00000
#
# [1607]	eval-auc:0.81854	train-auc:1.00000
#
# [1608]	eval-auc:0.81854	train-auc:1.00000
#
# [1609]	eval-auc:0.81854	train-auc:1.00000
#
# [1610]	eval-auc:0.81866	train-auc:1.00000
#
# [1611]	eval-auc:0.81866	train-auc:1.00000
#
# [1612]	eval-auc:0.81866	train-auc:1.00000
#
# [1613]	eval-auc:0.81866	train-auc:1.00000
#
# [1614]	eval-auc:0.81866	train-auc:1.00000
#
# [1615]	eval-auc:0.81866	train-auc:1.00000
#
# [1616]	eval-auc:0.81879	train-auc:1.00000
# [1617]	eval-auc:0.81879	train-auc:1.00000
#
# [1618]	eval-auc:0.81879	train-auc:1.00000
#
# 	Score 0.7307692307692307
#
#
# 100%|█████████████████████████████████████████████████████| 3/3 [02:13<00:00, 44.38s/it, best loss: 0.2692307692307693]
# The best hyperparameters are:
#
# {'colsample_bylevel ': 0.025, 'colsample_bynode': 0.755, 'colsample_bytree': 0.39, 'eta': 0.25, 'gamma': 0.18, 'max_depth': 69, 'min_child_weight': 1.0, 'n_estimators': 1069, 'reg_alpha': 0.597, 'reg_lambda': 0.906, 'subsample': 0.495}

# %%
best_hpy = {'colsample_bylevel ': 0.23500000000000001, 'colsample_bynode': 0.075, 'colsample_bytree': 0.585, 'eta': 0.325, 'gamma': 0.13, 'max_depth': 44, 'min_child_weight': 4.0, 'n_estimators': 4500, 'reg_alpha': 0.24, 'reg_lambda': 0.033, 'subsample': 0.885,
            
            
            'eval_metric': 'auc',
        'objective': 'binary:logistic',
        # Increase this number if you have more cores. Otherwise, remove it and it will default 
        # to the maxium number. 
        
        'nthread': 7,
        'booster': 'gbtree',
        'tree_method': 'exact',
        'silent': 1}

# %%
clf = xgb.XGBClassifier(gpu_id=0, **best_hpy)

# %%
clf.fit(X_train, y_train, verbose=3)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bylevel =0.23500000000000001, colsample_bynode=0.075,
#               colsample_bytree=0.585, eta=0.325, eval_metric='auc', gamma=0.13,
#               gpu_id=0, learning_rate=0.1, max_delta_step=0, max_depth=44,
#               min_child_weight=4.0, missing=None, n_estimators=4500, n_jobs=1,
#               nthread=7, objective='binary:logistic', random_state=0,
#               reg_alpha=0.24, reg_lambda=0.033, scale_pos_weight=1, silent=1,
#               subsample=0.885, tree_method='exact', verbosity=1)

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
clf.score(X_valid, y_valid)
# Out:
# 0.7307692307692307

# %%
sum(clf.feature_importances_[relev_features])/sum(clf.feature_importances_)
# Out:
# 1.0

# %%
all_relev_features = clf.feature_importances_

# %%
relev_features = all_relev_features.argsort()[-708:][::-1]

# %%
relev_features
# Out:
# array([ 367,   14,  177,  366,  364,   12,    6,   11,  190, 1223, 1336,
#           9,  679,   59,  175, 1015,  853,  170,  207, 1386,   39, 1184,
#         543,  611,  487,  586,   21,  757,  974, 1378,  749,    5, 1371,
#         217,  597, 1394, 1401,  685,  362,  812,   19, 1227,   96,   71,
#        1079,  719,  457,   69,    2,  835, 1407,  589,  518, 1370, 1054,
#         883,  688,  948,  162, 1264,  452, 1398,  600, 1358, 1321,  303,
#         585,  137,  577,  549,  660,  466, 1197,  964,  265,  665,  235,
#         817,  638,  768,  199, 1081,  492, 1022,  788,  456, 1195,  770,
#         990,  434,    0, 1036,  874, 1300, 1402,  542,  931,  237,  743,
#         797,  442, 1025,  113,  803, 1327,  594,  669,  478,  287,  953,
#         305, 1021, 1108,  123,  185, 1393,  786,  500,  783,  465, 1357,
#         183,  913,   22,  204,  928, 1213,  100,  263, 1366,  436,  957,
#         799,  664, 1055, 1413,  250,  829,  158,  991, 1033, 1097, 1084,
#         740,  136,  836, 1287,  841,  273,  486,  639,  653,  855,  277,
#         414,  203, 1214,  101,  714,  135,  933, 1330,  932,  171,  538,
#         756,  630,  514, 1152,  628, 1116,  255,  652,  269, 1114, 1278,
#         222, 1303,  796,   92,  254,  122,  801,  200, 1074, 1106,  924,
#         405, 1308,   95,  475,  649,  485,  154, 1395,  152,  707,  694,
#        1112, 1035,  712,  483,  792,  422, 1368, 1073, 1161,  650, 1219,
#          54, 1087, 1288,  643,  178, 1123, 1233,  993, 1199, 1095,  523,
#         846,  785,  110, 1185, 1153,  832,  907,  608,  168,  952, 1173,
#          94, 1389,  498,  941, 1115,  428, 1292,  242,  822,  451,  844,
#         647,  851, 1353, 1017, 1203,  791,  968,  691,  771,  276,   97,
#         426,  112,  513,  536,  631, 1168,  225,  821,   56, 1117, 1076,
#         752,  681,  142, 1196,  981,  661,  916,  759,  449, 1237, 1276,
#        1396, 1143, 1105,  826, 1313, 1034,  901, 1056,  927, 1294,  535,
#        1356,  464,  539, 1060,  165,   99,   84, 1121,  881,  805,  666,
#         157,   90,  503,  614,  102, 1216,  789, 1326,  596,  729,  934,
#         312, 1174, 1124,  955, 1405,  395,  777,   24,  579,  358,  739,
#        1406,  963,  972, 1043,  194,  410,   88,  421, 1062,  755, 1040,
#         236, 1204,  290,  105,  930,  563,  915,  827,  396,  411, 1392,
#         270, 1207,  917,  804,  259,  280,   42,  530, 1244,  256, 1263,
#        1225, 1404,  618, 1260, 1050,  576,  659, 1352,  180,  725, 1151,
#         763,  984,  195,  678,  504,  794, 1031, 1186,  663, 1349, 1318,
#         551,  654, 1354,  191, 1403,    8,  845,  690,  672,   33, 1058,
#         680,  612,  724,  606,  904, 1007, 1301,  210,  987,  824,  201,
#        1137,  807,   86,  212,  468,  459,  453,  675,  677,  511,  935,
#         617, 1140,  651,  392,  159, 1049, 1359,  573, 1295, 1148,  843,
#         911,  173,  568, 1210,  919, 1164,   48,  218,   72, 1248, 1238,
#         572, 1120,  484,  702,  847,  831,  219,  584,  497, 1009,  228,
#         570,  929,  481,  900, 1077,  632, 1296, 1215, 1100, 1311,  986,
#         527,  908,  863, 1096,  641,  238,   85,  609,  645,  515,  555,
#        1340,  463,  550,  939,  854, 1093,  141, 1149,  870,  938,  510,
#         196, 1160,  689,  294,  750,  834,  856,  129,  684,  114,  800,
#         994,   28,  189, 1374, 1310, 1253,  565,   93,  443,  192,   37,
#         557,  640,  956,  922, 1399,   78, 1262,  591, 1297,  620,  637,
#         197,  455,  289, 1229,  153,   30,  567,  865,  816, 1220, 1045,
#        1309,  562, 1023, 1290,  909,  174,  284,  814,  778, 1277, 1212,
#         613,  850, 1246,  315,  398,   98, 1127,  734, 1099, 1125, 1382,
#         561,  402,  167,  784,  209,  507,  391,  393,  482,  815, 1085,
#         906, 1266, 1037, 1118, 1135, 1156, 1202,  693, 1169,  646, 1239,
#         914, 1201,  119, 1363,  574,  790, 1180,  429, 1312, 1279,  648,
#         867, 1242, 1026,  670, 1286,  627, 1281,   57,  898,  227,  399,
#        1200, 1234, 1350, 1013,  132, 1383,  569, 1193,   75,  125, 1283,
#         891, 1030, 1254, 1362, 1051,  999, 1048,  160, 1172,  662,  715,
#        1080,   51,   49,  992,  575, 1205, 1122,  461,  164, 1367,  495,
#        1094,   58, 1090,  787,  239,  533,  888, 1273,  595,  420, 1249,
#        1086,  117,  656,  601,  668,  480,  121,  161,  825,  737,  211,
#        1307, 1150,  553, 1176,  701, 1024,  423, 1032, 1268,  793,  728,
#         718, 1053,  943,  541,  626,  633, 1103, 1289,  581,  223,  103,
#        1344,   80,  556, 1236, 1190,   53,  864,  474, 1170,  502,  782,
#        1154,  887,  447,  401,  545, 1126,  528,  147,  754,  969,  587,
#         473,  291,  226,   17,  546,  469, 1376,  182,  311, 1083,  876,
#          73, 1082, 1144, 1206,   91,  521,  837,   64, 1198, 1006,  976,
#         897,  949,  598,  522,  221,  380], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
clf.fit(X_train, y_train)
# Out:
# C:\Users\logiusti\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
clf.score(X_train, y_train)
# Out:
# 0.9924242424242424

# %%
clf.score(X_valid, y_valid)
# Out:
# 0.7417582417582418

# %%
clf.feature_importances_
# Out:
# array([0.00097625, 0.00034405, 0.        , ..., 0.00034607, 0.        ,
#        0.00125629])

# %%
len(np.where(clf.feature_importances_ == 0)[0])
# Out:
# 735
